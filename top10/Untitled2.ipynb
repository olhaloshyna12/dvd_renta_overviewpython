# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data-1691953392899.csv')
df.info
df.head
df.columns
# Out:
# Index(['actor_id', 'total_revenue'], dtype='object')

# %%
import seaborn as sns 
dfvp = pd.read_csv('data-1691953392899.csv')

# %%
plt.figure(figsize=(20,6)) 
sns.countplot(x='total_revenue', data=df) 
plt.show()

# %%
top_10 = (df['total_revenue'].value_counts()).iloc[:10]

# %%
top_10.plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['actor_id'],y=df['total_revenue'],data=df)
# Out:
# <Axes: xlabel='actor_id', ylabel='total_revenue'>
