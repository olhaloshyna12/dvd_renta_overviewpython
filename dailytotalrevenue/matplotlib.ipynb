# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data-1691941895100.csv')

# %%
df.pivot(index="payment_date", columns="country", values="daily_total_revenue").plot()
# Out:
# <Axes: xlabel='payment_date'>
