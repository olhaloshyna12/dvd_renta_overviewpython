# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data-1691951030118.csv')

# %%
 pd.set_option("display.max.columns", None)

# %%
df.head()
# Out:
#           country  store  revenue
# 0     Afghanistan      1    67.82
# 1         Algeria      1   259.41
# 2         Algeria      2    89.77
# 3  American Samoa      2    47.85
# 4          Angola      1   187.55

# %%
# %matplotlib inline

# %%
df.plot(x="country", y=["revenue"])
# Out:
# <Axes: xlabel='country'>

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["revenue"], df["country"])

# %%
df.plot(x="revenue", y="country", kind="scatter", fontsize=1)
# Out:
# <Axes: xlabel='revenue', ylabel='country'>

# %%
cat_totals = df.groupby("country")["revenue"].sum().sort_values()

# %%
cat_totals
# Out:
# country
# American Samoa                        47.85
# Lithuania                             63.78
# Saint Vincent and the Grenadines      64.82
# Tonga                                 64.84
# Afghanistan                           67.82
#                                      ...
# Mexico                              2984.82
# Japan                               3122.51
# United States                       3685.31
# China                               5251.03
# India                               6034.78
# Name: revenue, Length: 108, dtype: float64

# %%
 cat_totals.plot(kind="barh", fontsize=1)
# Out:
# <Axes: ylabel='country'>

# %%
plt.style.use('classic')
